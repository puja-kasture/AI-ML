# %% [markdown]
# # Question 1
#
# Research on whether addition, subtraction, multiplication, division, floor division, and modulo operations
# be performed on complex numbers. Based on your study, implement a Python program to demonstrate
# these operations.

# %%
cnum1=complex(input("Enter first complex number:"))
cnum2=complex(input("Enter second complex number:"))
add=cnum1+cnum2
sub=cnum1-cnum2
mul=cnum1*cnum2
div=cnum1/cnum2
#mod=cnum1%cnum2                         Can't take mod of complex numbers
#fdiv=cnum1//cnum2                       Can't take floor of complex numbers
print("Addition: ",add)
print("Subtraction: ",sub)
print("Multiplication: ",mul)
print("Division: ",div)
#print("Modulo: ",mod)
#print("Floor division: ",fdiv)
# Out:
# Enter first complex number:5+3j
# Enter second complex number:2+1j
# Addition:  (7+4j)
# Subtraction:  (3+2j)
# Multiplication:  (7+11j)
# Division:  (2.6+0.2j)

# %% [markdown]
# # Question 2
#
# Research on range() functions and its parameters. Create a markdown cell and write in your own words
# (no copy-paste from google please) what you understand about it. Implement a small program of your
# choice on the same.

# %% [raw]
# range(start, stop, step)
#
# start is nothing but starting of range
# stop is nothing but ending of range
# step is nothing but if any incrementation should be there, then it can be done using step.
#
# start and step are optional.

# %%
for i in range(1,10):
    if(i%2==0):
        print(i)
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# # Question 3
#
# Consider two numbers. Perform their subtraction and if the result of subtraction is greater than 25, print
# their multiplication result else print their division result.

# %%
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
sub=num1-num2
if(sub>25):
    print("Multiplication is: ",(num1*num2))
else:
    print("Division is: ",(num1/num2))
# Out:
# Enter first number:20
# Enter second number:50
# Division is:  0.4

# %% [markdown]
# # Question 4
#
# Consider a list of 10 elements of integer values. If the number in the list is divisible by 2, print the result as
# "square of that number minus 2".

# %%
lst=[20,30,10,29,39,5,56,89,45,87]
for i in lst:
    if(i%2==0):
        print((i^2)-2)
# Out:
# 20
# 26
# 6
# 56

# %% [markdown]
# # Question 5
#
# Consider a list of 10 elements. Print all the elements in the list which are greater than 7 when that number
# is divided 2.

# %%
lst1=[20,30,10,29,39,5,56,89,45,87]
for i in lst1:
    if((i/2)>7):
        print(i)
# Out:
# 20
# 30
# 29
# 39
# 56
# 89
# 45
# 87
